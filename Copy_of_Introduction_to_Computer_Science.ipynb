# %% [markdown]
# <a href="https://colab.research.google.com/github/srostron2112/compsci/blob/master/Copy_of_Introduction_to_Computer_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to USCAiken and Applied Computer Science program ​
#
#
# 1.   Applied Computer Science (no concentration)​
# 2.   Cybersecurity​
# 3.   Applied Gaming

# %% [markdown]
# ## Try:  What is your intended major?  Please write your answer here!

# %% [markdown]
# Now let's do a poll!  Are you able to see a poll pop up from the blackboard collaborator ultra?  Check it!

# %% [markdown]
# # About the course.
#
#
# *   This course is designed to help students with no prior exposure to computer science or programming learn to think computationally and write programs to solve real-life problems. The course focuses on problem analysis and the development of algorithms and computer programs in a modern high-level language. ​
# *   This course is mainly for students who want to pursue a major in computer science.​

# %% [markdown]
# # About Instructor  -- Yilian Zhang
#
#
# *   Computer Science Courses ---  Networking/ Web Programming/Unix system programming​
# *   Math courses – Calculus/ numerical methods
#
# *   Link to personal webpage:  [https://yilianz.github.io/](https://yilianz.github.io/)

# %% [markdown]
# # Course Logistic
#
# ## Everything is on [blackboard](https://blackboard.usca.edu)
#
# ![szoter_annotated_image (3).jpeg](data:image/jpeg;base64,...)
#
# *   Get Started
# *   Lessons
# *   Questions and Answers
# *   Virtual office hour

# %% [markdown]
# ## Try:   Create a thread in ICE Break forum in Discussion Board
#
# ### Test your written communication skills

# %% [markdown]
# # Know your classmate
# ### Test your oral communication skills
#
# Please introduce yourself. ​
#
# * Who you are?​
#
# * Your major and concentration. ​
#
# * What's your expectation of this class?​
#
# * Anything else that you’d like to let us know.

# %% [markdown]
# # Syllabus Review
#
#
# *   Textbook
# *   Course Objectives
# *   Course delivery
# *   Homework and test

# %% [markdown]
# # Challenge and Tips for future computer science majors
# ###Can you get a job after you get the computer science degree?​
#
# Yes.   IF​
#
#
# *  Communication Skills  --- Oral/ Writing​
#
# *  Tech Skills ​
#
# *   Know how to do it.​
#
# *   Know how to search and investigate if you don’t know how to do it. ​
#
# *   Networking
#
#
# > > Career Service  - Many internship/part time opportunities
#
# > > Pay attention to research opportunity at school

# %% [markdown]
# # Components of Computer Science --- Programming
#
# Python
#
# Let's try the code on google colad -  a free Jupyter notebook that allows you share live executable documents.

# %%
3+4-5
# Out:
# 2

# %%
print("Hello world")
# Out:
# Hello world

# %%
name = "yilian"
welcome = "hello " + name
print(welcome)
# Out:
# helloyilian

# %% [markdown]
# ### Try:  Create Python codes that calculate  5 - 3 * 2   and  ( 5-3)*2.

# %% [markdown]
# ### Try: Create Python codes that print a welcome message.
